# %%
import csv
import os
import time
import ujson
from random import randint
from typing import Dict, List, Any
import json

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
def write_authors(list1, file_name):
    with open(file_name, 'w', encoding='utf-8') as f:
        for i in range(0, len(list1)):
            f.write(list1[i] + '\n')

def initCrawlerScraper(seed, page_limit):
    # Initialize driver for Chrome
    webOpt = webdriver.ChromeOptions()
    webOpt.add_experimental_option('excludeSwitches', ['enable-logging'])
    webOpt.add_argument('--ignore-certificate-errors')
    webOpt.add_argument('--incognito')
    webOpt.add_argument('--headless')  # Set headless mode
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=webOpt, service_log_path=os.devnull)

    driver.get(seed)  # Start with the original link

    Links = []  # Array with pureportal profiles URL
    pub_data = []  # To store publication information for each pureportal profile
    next_link = driver.find_element(By.CSS_SELECTOR, ".nextLink")
    next_link_enabled = next_link.is_enabled()

    page_count = 0  # Counter for the number of pages crawled

    while next_link_enabled and page_count < page_limit:
        page_count += 1

        page = driver.page_source
        bs = BeautifulSoup(page, "lxml")

        # Extracting exact URL by accessing the href attribute
        for link in bs.findAll('a', class_='link person'):
            url = link['href']
            Links.append(url)

        # Click on Next button to visit the next page
        try:
            if driver.find_element(By.CSS_SELECTOR, ".nextLink"):
                element = driver.find_element(By.CSS_SELECTOR, ".nextLink")
                driver.execute_script("arguments[0].click();", element)
            else:
                next_link_enabled = False
        except NoSuchElementException:
            break

    print("Crawler has found", len(Links), "pureportal profiles")
    write_authors(Links, 'Authors_URL.txt')

    print("Scraping publication data for", len(Links), "pureportal profiles...")

    # Load the URLs from the file
    with open('Authors_URL.txt', 'r') as f:
        urls = f.read().splitlines()

    # Crawl data from 10 URLs
    for i in range(8):
        if i >= len(urls):
            break

        url = urls[i]

        # Visit each link to get data
        time.sleep(1)
        driver.get(url)
        try:
            if driver.find_elements(By.CSS_SELECTOR, ".portal_link.btn-primary.btn-large span"):
                elements = driver.find_elements(By.CSS_SELECTOR, ".portal_link.btn-primary.btn-large span")
                for span in elements:
                    try:
                        if span.text:
                            if "research output".lower() in span.text.lower():
                                driver.execute_script("arguments[0].click();", span)
                                driver.get(driver.current_url)
                                # Get name of Author
                                name = driver.find_element(By.CSS_SELECTOR, "div[class='header person-details']>h1")
                                r = requests.get(driver.current_url)
                                page = r.content
                                bs = BeautifulSoup(page, "lxml")
                                rows = bs.findAll("div", {"class": "result-container"})
                                for row in rows:
                                    data: Dict[str, Any] = {}
                                    data['name'] = row.h3.a.text.strip()
                                    data['pub_url'] = row.h3.a['href']
                                    date = row.find("span", class_="date")
                                    data['cu_author'] = name.text if name else ''
                                    data['date'] = date.text if date else ''
                                    pub_data.append(data)
                                    print("Publication Name:", data['name'])
                                    print("Publication URL:", data['pub_url'])
                                    print("CU Author:", data['cu_author'])
                                    print("Date:", data['date'])
                                    print("\n")
                    except StaleElementReferenceException:
                        continue

        except NoSuchElementException:
            break

    # Writing publication data to a JSON file
    with open('scraper_results.json', 'w', encoding='utf-8') as json_file:
        json.dump(pub_data, json_file, ensure_ascii=False, indent=4)

seed_link = 'https://pureportal.coventry.ac.uk/en/publications/'
page_limit = 1
initCrawlerScraper(seed_link, page_limit)
# Out:
# /var/folders/0y/7jn0pyws3cjb9ytf9k8s1_0w0000gn/T/ipykernel_11583/3265082999.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=webOpt, service_log_path=os.devnull)
# Crawler has found 70 pureportal profiles
# Scraping publication data for 70 pureportal profiles...
# Publication Name: Bletchley Park in Myth and Memory
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/bletchley-park-in-myth-and-memory
# CU Author: Thomas Knowles
# Date: 2024
#
#
# Publication Name: Book Review: Paradoxa# 31: Climate Fictions. Edited by Alison Sperling
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/book-review-paradoxa-31-climate-fictions-edited-by-alison-sperlin
# CU Author: Thomas Knowles
# Date: 2022
#
#
# Publication Name: J. G. Ballard and the Sciences
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/j-g-ballard-and-the-sciences
# CU Author: Thomas Knowles
# Date: 30 Jan 2020
#
#
# Publication Name: J. G. Ballard and Making: An Experiment in Collaborative Practice
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/j-g-ballard-and-making-an-experiment-in-collaborative-practice
# CU Author: Thomas Knowles
# Date: 2019
#
#
# Publication Name: J. G. Ballard and Making
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/j-g-ballard-and-making
# CU Author: Thomas Knowles
# Date: Sept 2019
#
#
# Publication Name: Philip K. Dick Special Issue
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/philip-k-dick-special-issue
# CU Author: Thomas Knowles
# Date: Jul 2019
#
#
# Publication Name: Philip K. Dick special section: Thomas Knowles with Terence Sawyers: Guest Editorial
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/philip-k-dick-special-section-thomas-knowles-with-terence-sawyers
# CU Author: Thomas Knowles
# Date: Jul 2019
#
#
# Publication Name: Weird Border Crossings in China Miéville’s “Looking for Jake”, “The Tain” and “Säcken”
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/weird-border-crossings-in-china-mi%C3%A9villes-looking-for-jake-the-ta
# CU Author: Thomas Knowles
# Date: 31 Dec 2019
#
#
# Publication Name: Conference report on ‘J. G. Ballard and the Sciences’
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/conference-report-on-j-g-ballard-and-the-sciences
# CU Author: Thomas Knowles
# Date: 2018
#
#
# Publication Name: J. G. Ballard and the 'Natural' World
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/j-g-ballard-and-the-natural-world
# CU Author: Thomas Knowles
# Date: 2 Oct 2018
#
#
# Publication Name: Special issue: J.G. Ballard and the ‘Natural’ World
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/special-issue-jg-ballard-and-the-natural-world
# CU Author: Thomas Knowles
# Date: 2018
#
#
# Publication Name: The Machinery of Progress: review of Colson Whitehead, The Underground Railroad
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/the-machinery-of-progress-review-of-colson-whitehead-the-undergro
# CU Author: Thomas Knowles
# Date: Jul 2018
#
#
# Publication Name: ‘Deep Assignments': review of Rick McGrath ed. J. G. Ballard: Deep Ends 2016
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/deep-assignments-review-of-rick-mcgrath-ed-j-g-ballard-deep-ends-
# CU Author: Thomas Knowles
# Date: 2018
#
#
# Publication Name: Review of Mark Sandy, et al. Decadent Romanticism: 1790-1914
# Publication URL: https://pureportal.coventry.ac.uk/en/publications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/anti-suit-injunctions-under-ohada-law-could-this-mechanism-turn-t
# CU Author: Margaret Liu
# Date: 20 Nov 2022
#
#
# Publication Name: The Privity of Contract Under the Contracts (Rights of Third Parties) Act: Frustrate or Facilitate the Participation of Third Parties to the Arbitration?
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/the-privity-of-contract-under-the-contracts-rights-of-third-parti
# CU Author: Margaret Liu
# Date: 22 Jun 2022
#
#
# Publication Name: Third party arbitration in the UK: critically assessing the applicable rules of the joinder of two different proceedings under the Brussels Recast Regulation (EU 1215/2012)
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/third-party-arbitration-in-the-uk-critically-assessing-the-applic
# CU Author: Margaret Liu
# Date: 20 May 2021
#
#
# Publication Name: Flipped for Critical Thinking: Evaluating the Effectiveness of a Novel Teaching Approach in Postgraduate Law Modules
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/flipped-for-critical-thinking-evaluating-the-effectiveness-of-a-n-2
# CU Author: Margaret Liu
# Date: 19 Jun 2020
#
#
# Publication Name: The Impact of the UK’s BREXIT on Anti-Suit Injunctions
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/the-impact-of-the-uks-brexit-on-anti-suit-injunctions
# CU Author: Margaret Liu
# Date: 13 Oct 2020
#
#
# Publication Name: The State of International Arbitration in Kenya
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/the-state-of-international-arbitration-in-kenya
# CU Author: Margaret Liu
# Date: Mar 2020
#
#
# Publication Name: Chinese Migrant Children: Do They Have the Right to Education?
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/chinese-migrant-children-do-they-have-the-right-to-education
# CU Author: Margaret Liu
# Date: 22 Jul 2019
#
#
# Publication Name: Flipped For Critical Thinking: Evaluating The Effectiveness Of A Novel Teaching Approach In Postgraduate Law Modules
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/flipped-for-critical-thinking-evaluating-the-effectiveness-of-a-n
# CU Author: Margaret Liu
# Date: 2019
#
#
# Publication Name: A Departure from West Tankers after Brexit? Anti-suit Injunctions in the UK Directed to Parties in EU National Courts
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-departure-from-west-tankers-after-brexit-anti-suit-injunctions-
# CU Author: Margaret Liu
# Date: Dec 2018
#
#
# Publication Name: Revisiting Anti-suit Injunctions Post Brexit: Some Lessons from US
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/revisiting-anti-suit-injunctions-post-brexit-some-lessons-from-us
# CU Author: Margaret Liu
# Date: 23 Mar 2018
#
#
# Publication Name: Arbitration in the Republic of Ireland after Brexit
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/arbitration-in-the-republic-of-ireland-after-brexit
# CU Author: Margaret Liu
# Date: 29 Dec 2017
#
#
# Publication Name: Does the Will of the Parties Supersede the Sovereignty of the State? Anti-suit Injunctions in the UK Post-Brexit
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/does-the-will-of-the-parties-supersede-the-sovereignty-of-the-sta
# CU Author: Margaret Liu
# Date: 2017
#
#
# Publication Name: Is this the end? The effect of Brexit on the arbitration of EU competition laws in the UK
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/is-this-the-end-the-effect-of-brexit-on-the-arbitration-of-eu-com
# CU Author: Margaret Liu
# Date: 2017
#
#
# Publication Name: Third party arbitration under English law
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/third-party-arbitration-under-english-law
# CU Author: Margaret Liu
# Date: 5 Oct 2016
#
#
# Publication Name: 3D forensic science: An introductory statement from the members of the Forensic Capability Network (FCN) Visual Technologies Research Group (VTRG)
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/3d-forensic-science-an-introductory-statement-from-the-members-of
# CU Author: Rachael Carew
# Date: Jun 2023
#
#
# Publication Name: An ethical framework for the creation and use of 3D printed human remains in crime reconstruction
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/an-ethical-framework-for-the-creation-and-use-of-3d-printed-human
# CU Author: Rachael Carew
# Date: Jul 2023
#
#
# Publication Name: Drilling down into ethics: A thematic review of ethical considerations for the creation and use of 3D printed human remains in crime reconstruction
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/drilling-down-into-ethics-a-thematic-review-of-ethical-considerat
# CU Author: Rachael Carew
# Date: May 2023
#
#
# Publication Name: Exploring public perceptions of creating and using 3D printed human remains
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/exploring-public-perceptions-of-creating-and-using-3d-printed-hum
# CU Author: Rachael Carew
# Date: Jul 2023
#
#
# Publication Name: A multi-method assessment of 3D printed micromorphological osteological features
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-multi-method-assessment-of-3d-printed-micromorphological-osteol
# CU Author: Rachael Carew
# Date: Sept 2022
#
#
# Publication Name: A survey of case studies on the use of forensic three-dimensional printing in England and Wales
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-survey-of-case-studies-on-the-use-of-forensic-three-dimensional
# CU Author: Rachael Carew
# Date: Nov 2022
#
#
# Publication Name: 3D forensic science: A new field integrating 3D imaging and 3D printing in crime reconstruction
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/3d-forensic-science-a-new-field-integrating-3d-imaging-and-3d-pri
# CU Author: Rachael Carew
# Date: 2021
#
#
# Publication Name: Assessment of the accuracy of 3D printed teeth by various 3D printers in forensic odontology
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/assessment-of-the-accuracy-of-3d-printed-teeth-by-various-3d-prin
# CU Author: Rachael Carew
# Date: Nov 2021
#
#
# Publication Name: Experimental assessment of the surface quality of 3D printed bones
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/experimental-assessment-of-the-surface-quality-of-3d-printed-bone
# CU Author: Rachael Carew
# Date: 3 Sept 2021
#
#
# Publication Name: Suitability of 3D printing cranial trauma: prospective novel applications and limitations of 3D replicas
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/suitability-of-3d-printing-cranial-trauma-prospective-novel-appli
# CU Author: Rachael Carew
# Date: Nov 2021
#
#
# Publication Name: Achieving accurate estimates of fetal gestational age and personalised predictions of fetal growth based on data from an international prospective cohort study: a population-based machine learning study
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/achieving-accurate-estimates-of-fetal-gestational-age-and-persona
# CU Author: Rachael Carew
# Date: 1 Jul 2020
#
#
# Publication Name: An Overview of 3D Printing in Forensic Science: The Tangible Third-Dimension
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/an-overview-of-3d-printing-in-forensic-science-the-tangible-third
# CU Author: Rachael Carew
# Date: Sept 2020
#
#
# Publication Name: A step-by-step method for producing 3D crania models from CT data
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-step-by-step-method-for-producing-3d-crania-models-from-ct-data
# CU Author: Rachael Carew
# Date: Dec 2020
#
#
# Publication Name: Digital Dilemma 2018
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/digital-dilemma-2018
# CU Author: Rachael Carew
# Date: 6 Mar 2020
#
#
# Publication Name: Digital Dilemma 2018: Digital Presentations in Biological Anthropology and Bioarchaeology
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/digital-dilemma-2018-digital-presentations-in-biological-anthropo
# CU Author: Rachael Carew
# Date: 17 Dec 2020
#
#
# Publication Name: Accuracy of computed radiography in osteometry: A comparison of digital imaging techniques and the effect of magnification
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/accuracy-of-computed-radiography-in-osteometry-a-comparison-of-di
# CU Author: Rachael Carew
# Date: Dec 2019
#
#
# Publication Name: A Preliminary Investigation into the Accuracy of 3D Modeling and 3D Printing in Forensic Anthropology Evidence Reconstruction
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-preliminary-investigation-into-the-accuracy-of-3d-modeling-and-
# CU Author: Rachael Carew
# Date: Mar 2019
#
#
# Publication Name: Imaging in forensic science: Five years on
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/imaging-in-forensic-science-five-years-on
# CU Author: Rachael Carew
# Date: Mar 2019
#
#
# Publication Name: Precision of recumbent crown-heel length when using an infantometer
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/precision-of-recumbent-crown-heel-length-when-using-an-infantomet
# CU Author: Rachael Carew
# Date: 14 Nov 2016
# Publication Name: A CFD-Based Numerical Evaluation, Assessment and Optimization of Conjugate Heat Transfer for Aerodynamic Cooling of a Wheel-Hub-Motors in Micro-Mobility Vehicles
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-cfd-based-numerical-evaluation-assessment-and-optimization-of-c
# CU Author: Evangelos Gkanas
# Date: 11 Apr 2023
#
#
# Publication Name: Comparison of the effect of one-way and two-way fire-wind coupling on the modelling of wildland fire propagation dynamics
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/comparison-of-the-effect-of-one-way-and-two-way-fire-wind-couplin
# CU Author: Evangelos Gkanas
# Date: Dec 2022
#
#
# Publication Name: Development and Testing of Ni-Cu Bimetallic Catalysts for Effective Syngas Production via Low-Temperature Methane Steam Reforming
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/development-and-testing-of-ni-cu-bimetallic-catalysts-for-effecti
# CU Author: Evangelos Gkanas
# Date: 6 Dec 2022
#
#
# Publication Name: Heat Transfer Performance Enhancement On Wheel Hub Motor With Fin Adjoint Optimization
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/heat-transfer-performance-enhancement-on-wheel-hub-motor-with-fin
# CU Author: Evangelos Gkanas
# Date: 1 Oct 2022
#
#
# Publication Name: Metal-Hydride-Based Hydrogen Storage as Potential Heat Source for the Cold Start of PEMFC in Hydrogen-Powered Coaches:  A Comparative Study of Various Materials and Thermal Management Techniques
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/metal-hydride-based-hydrogen-storage-as-potential-heat-source-for
# CU Author: Evangelos Gkanas
# Date: 1 Nov 2022
#
#
# Publication Name: Ni/Co Bimetallic Flower-Like Metal-Organic Frameworks with Enhanced Performance for High-PowerEnergy Storage Applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/nico-bimetallic-flower-like-metal-organic-frameworks-with-enhance
# CU Author: Evangelos Gkanas
# Date: 28 Oct 2022
#
#
# Publication Name: Synthesis and Characterisation of Iron Oxide Nanoparticles with Tunable Sizes by Hydrothermal Method
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/synthesis-and-characterisation-of-iron-oxide-nanoparticles-with-t
# CU Author: Evangelos Gkanas
# Date: 17 Feb 2022
#
#
# Publication Name: Adsorption of lead on the surfaces of pristine and B, Si and N-doped graphene
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/adsorption-of-lead-on-the-surfaces-of-pristine-and-b-si-and-n-dop
# CU Author: Evangelos Gkanas
# Date: 1 Jan 2021
#
#
# Publication Name: Self-diffusion in garnet-type Li7La3Zr2O12 solid electrolytes
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/self-diffusion-in-garnet-type-li7la3zr2o12-solid-electrolytes
# CU Author: Evangelos Gkanas
# Date: 11 Jan 2021
#
#
# Publication Name: Study on the operation and energy demand of dual-stage Metal Hydride Hydrogen Compressors under effective thermal management
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/study-on-the-operation-and-energy-demand-of-dual-stage-metal-hydr
# CU Author: Evangelos Gkanas
# Date: 18 Aug 2021
#
#
# Publication Name: Encapsulation and substitution of Fe in C12A7 (12CaO⋅ 7Al2O3)
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/encapsulation-and-substitution-of-fe-in-c12a7-12cao-7al2o3
# CU Author: Evangelos Gkanas
# Date: 27 Jan 2020
#
#
# Publication Name: Hydrogen Technologies for Mobility and Stationary Applications: Hydrogen Production, Storage and Infrastructure Development
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/hydrogen-technologies-for-mobility-and-stationary-applications-hy
# CU Author: Evangelos Gkanas
# Date: 9 Sept 2020
#
#
# Publication Name: Life Cycle Costing Analysis: Tools and Applications for Determining Hydrogen Production Cost for Fuel Cell Vehicle Technology
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/life-cycle-costing-analysis-tools-and-applications-for-determinin
# CU Author: Evangelos Gkanas
# Date: 23 Jul 2020
#
#
# Publication Name: Numerical Investigation on the Operation and Energy Demand of a Seven-Stage Metal Hydride Hydrogen Compression System for Hydrogen Refuelling Stations
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/numerical-investigation-on-the-operation-and-energy-demand-of-a-s
# CU Author: Evangelos Gkanas
# Date: 1 Mar 2020
#
#
# Publication Name: Sustainable hydrogen production via LiH hydrolysis for unmanned air vehicle (UAV) applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/sustainable-hydrogen-production-via-lih-hydrolysis-for-unmanned-a
# CU Author: Evangelos Gkanas
# Date: 14 Feb 2020
#
#
# Publication Name: Thermal characteristics of an air‐cooled open‐cathode proton exchange membrane fuel cell stack via numerical investigation
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/thermal-characteristics-of-an-aircooled-opencathode-proton-exchan
# CU Author: Evangelos Gkanas
# Date: 1 Nov 2020
#
#
# Publication Name: Dinitrogen activation by zirconium dimer loaded C60
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/dinitrogen-activation-by-zirconium-dimer-loaded-c60
# CU Author: Evangelos Gkanas
# Date: 31 May 2019
#
#
# Publication Name: Heat management on rectangular metal hydride tanks for green building applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/heat-management-on-rectangular-metal-hydride-tanks-for-green-buil
# CU Author: Evangelos Gkanas
# Date: 19 Jul 2019
#
#
# Publication Name: High efficient catalytic degradation of tetracycline and ibuprofen using visible light driven novel Cu/Bi2Ti2O7/rGO nanocomposite: Kinetics, intermediates and mechanism
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/high-efficient-catalytic-degradation-of-tetracycline-and-ibuprofe
# CU Author: Evangelos Gkanas
# Date: 25 Apr 2019
#
#
# Publication Name: Mg6MnO8 as a Magnesium-Ion Battery Material: Defects, Dopants and Mg-Ion Transport
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/mgsub6submnosub8sub-as-a-magnesium-ion-battery-material-defects-d
# CU Author: Evangelos Gkanas
# Date: 21 Aug 2019
#
#
# Publication Name: Study on the Hydrogenation of a Mm-based AB5-Intermetallic for Sustainable Building Applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/study-on-the-hydrogenation-of-a-mm-based-ab5-intermetallic-for-su
# CU Author: Evangelos Gkanas
# Date: Nov 2019
#
#
# Publication Name: Synthesis, characterisation and hydrogen sorption properties of mechanically alloyed Mg(Ni1-xMnx)2
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/synthesis-characterisation-and-hydrogen-sorption-properties-of-me
# CU Author: Evangelos Gkanas
# Date: Sept 2019
#
#
# Publication Name: Catalytic performance of Ni-Cu/Al2O3 for effective syngas production by methanol steam reforming
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/catalytic-performance-of-ni-cual2o3-for-effective-syngas-producti
# CU Author: Evangelos Gkanas
# Date: 15 Nov 2018
#
#
# Publication Name: Hydrogenation behavior in rectangular metal hydride tanks under effective heat management processes for green building applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/hydrogenation-behavior-in-rectangular-metal-hydride-tanks-under-e
# CU Author: Evangelos Gkanas
# Date: 1 Jan 2018
#
#
# Publication Name: Life Cycle Costing Analysis for Determining Hydrogen Cost for Mobility Applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/life-cycle-costing-analysis-for-determining-hydrogen-cost-for-mob
# CU Author: Evangelos Gkanas
# Date: 2018
#
#
# Publication Name: Metal Hydride Hydrogen Compression Systems–Materials, Applications and Numerical Analysis
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/metal-hydride-hydrogen-compression-systemsmaterials-applications-
# CU Author: Evangelos Gkanas
# Date: 20 Jul 2018
#
#
# Publication Name: Metal hydrides: Modeling of metal hydrides to be operated in a fuel cell
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/metal-hydrides-modeling-of-metal-hydrides-to-be-operated-in-a-fue
# CU Author: Evangelos Gkanas
# Date: 18 Aug 2018
#
#
# Publication Name: Novel hybrid-powered stand alone autonomous unmanned aerial vehicle (AUV) ground base station
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/novel-hybrid-powered-stand-alone-autonomous-unmanned-aerial-vehic
# CU Author: Evangelos Gkanas
# Date: 29 Aug 2018
#
#
# Publication Name: Parametric Study on the Heat Management of Metal Hydride Tanks for Sustainable Building Applications
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/parametric-study-on-the-heat-management-of-metal-hydride-tanks-fo
# CU Author: Evangelos Gkanas
# Date: 27 Feb 2018
#
#
# Publication Name: A review of a stand-alone Hydrogen system application for private houses in Greece and the use of Phase change materials in their building construction
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-review-of-a-stand-alone-hydrogen-system-application-for-private
# CU Author: Evangelos Gkanas
# Date: 10 Oct 2017
#
#
# Publication Name: Experimental and Numerical Study of Low Temperature Methane Steam Reforming for Hydrogen Production
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/experimental-and-numerical-study-of-low-temperature-methane-steam
# CU Author: Evangelos Gkanas
# Date: 25 Dec 2017
#
#
# Publication Name: Numerical analysis of candidate materials for multi-stage metal hydride hydrogen compression processes
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/numerical-analysis-of-candidate-materials-for-multi-stage-metal-h
# CU Author: Evangelos Gkanas
# Date: Oct 2017
#
#
# Publication Name: PCMs for Residential Building Applications: A Short Review Focused on Disadvantages and Proposals for Future Development
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/pcms-for-residential-building-applications-a-short-review-focused
# CU Author: Evangelos Gkanas
# Date: 28 Aug 2017
#
#
# Publication Name: The Benefits of Lean through an Analysis and Improvement of an Existing Production Line
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/the-benefits-of-lean-through-an-analysis-and-improvement-of-an-ex
# CU Author: Evangelos Gkanas
# Date: 9 May 2017
#
#
# Publication Name: Effective thermal management of a cylindrical MgH2 tank including thermal coupling with an operating SOFC and the usage of extended surfaces during the dehydrogenation process
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/effective-thermal-management-of-a-cylindrical-mgh2-tank-including-2
# CU Author: Evangelos Gkanas
# Date: 13 Apr 2016
#
#
# Publication Name: Efficient hydrogen storage in up-scale metal hydride tanks as possible metal hydride compression agents equipped with aluminium extended surfaces
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/efficient-hydrogen-storage-in-up-scale-metal-hydride-tanks-as-pos-2
# CU Author: Evangelos Gkanas
# Date: 6 Jul 2016
#
#
# Publication Name: Structure, Microstructure and hydrogen storage properties of melt-spun V55Ti21Mn17Fe7 and V55Ti21Cr17Fe7
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/structure-microstructure-and-hydrogen-storage-properties-of-melt--2
# CU Author: Evangelos Gkanas
# Date: 2016
#
#
# Publication Name: A complete transport validated model on a zeolite membrane for carbon dioxide permeance and capture
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/a-complete-transport-validated-model-on-a-zeolite-membrane-for-ca-2
# CU Author: Evangelos Gkanas
# Date: 5 Jan 2015
#
#
# Publication Name: Numerical study on a two-stage Metal Hydride Hydrogen Compression system
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/numerical-study-on-a-two-stage-metal-hydride-hydrogen-compression-2
# CU Author: Evangelos Gkanas
# Date: 5 Oct 2015
#
#
# Publication Name: “Substitutionability” of the Critical Raw Materials in Energy Applications: A Short Review and Perspectives
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/substitutionability-of-the-critical-raw-materials-in-energy-appli
# CU Author: Evangelos Gkanas
# Date: 9 Oct 2015
#
#
# Publication Name: Chemical characterization of particulate matter (PM) and source apportionment study during winter and summer period for the city of Kozani, Greece
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/chemical-characterization-of-particulate-matter-pm-and-source-app-2
# CU Author: Evangelos Gkanas
# Date: 13 Mar 2014
#
#
# Publication Name: High-temperature activated AB2 nanopowders for metal hydride hydrogen compression
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/high-temperature-activated-ab2-nanopowders-for-metal-hydride-hydr-2
# CU Author: Evangelos Gkanas
# Date: 25 Mar 2014
#
#
# Publication Name: Microstuctural analysis and determination of PM10 emission sources in an industrial Mediterranean city
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/microstuctural-analysis-and-determination-of-pm10-emission-source-2
# CU Author: Evangelos Gkanas
# Date: 29 Apr 2014
#
#
# Publication Name: In vitro magnetic hyperthermia response of iron oxide MNP’s incorporated in DA3, MCF-7 and HeLa cancer cell lines
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/in-vitro-magnetic-hyperthermia-response-of-iron-oxide-mnps-incorp-2
# CU Author: Evangelos Gkanas
# Date: Jul 2013
# Publication Name: Modeling and Simulation for Absorption-Desorption Cyclic Process on a Three-Stage Metal Hydride Hydrogen Compressor
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/modeling-and-simulation-for-absorption-desorption-cyclic-process--2
# CU Author: Evangelos Gkanas
# Date: 2013
#
#
# Publication Name: Nanotechnology and Innovation: Recent Status and the Strategic Implication for the Formation of High Tech Clusters in Greece, in between a Global Economic Crisis
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/nanotechnology-and-innovation-recent-status-and-the-strategic-imp-2
# CU Author: Evangelos Gkanas
# Date: Mar 2013
#
#
# Publication Name: Polymer-stable magnesium nanocomposites prepared by laser ablation for efficient hydrogen storage
# Publication URL: https://pureportal.coventry.ac.uk/en/publications/polymer-stable-magnesium-nanocomposites-prepared-by-laser-ablatio-2
# CU Author: Evangelos Gkanas
# Date: 30 Aug 2013
